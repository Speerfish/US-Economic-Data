# %% [markdown]
# ## Jupyter Notebook: Parsing CSV file and Visualizing Data

# %% [markdown]
# In this notebook, we will load a CSV file, convert it to a pandas DataFrame, and then create multiple county specific map visualizations using matplotlib and seaborn

# %%
pip install pandas matplotlib seaborn

# %% [markdown]
# # Step 1: Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Step 2: Load the CSV file into a pandas DataFrame

# %%
df = pd.read_csv('MEHOINUSA672N.csv', parse_dates=['DATE'])

# %% [markdown]
# ## Step 3: Inspect the data

# %%
print(df.info())
df.head(15)  # Display the first few rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DATE           40 non-null     datetime64[ns]
#  1   MEHOINUSA672N  40 non-null     int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 772.0 bytes
# None
#          DATE  MEHOINUSA672N
# 0  1984-01-01          58930
# 1  1985-01-01          60050
# 2  1986-01-01          62280
# 3  1987-01-01          63060
# 4  1988-01-01          63530
# 5  1989-01-01          64610
# 6  1990-01-01          63830
# 7  1991-01-01          61960
# 8  1992-01-01          61450
# 9  1993-01-01          61150
# 10 1994-01-01          61800
# 11 1995-01-01          63770
# 12 1996-01-01          64710
# 13 1997-01-01          66050
# 14 1998-01-01          68470

# %% [markdown]
# ## Step 4: Plot time series line graph

# %%
# Plot the time series data
plt.figure(figsize=(12, 6))
sns.lineplot(x='DATE', y='MEHOINUSA672N', data=df)

# Add labels and title
plt.title('Median Household Income Over Time')
plt.xlabel('Date')
plt.ylabel('Median Household Income - 2023 C-CPI-U Dollars')

# Display the plot
plt.grid(True)
plt.show()
