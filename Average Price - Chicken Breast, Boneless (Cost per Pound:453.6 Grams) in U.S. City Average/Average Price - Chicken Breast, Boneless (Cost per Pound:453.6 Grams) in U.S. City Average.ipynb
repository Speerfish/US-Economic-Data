# %% [markdown]
# ## Jupyter Notebook: Parsing CSV file and Visualizing Data

# %% [markdown]
# In this notebook, we will load a CSV file, convert it to a pandas DataFrame, and then create multiple county specific map visualizations using matplotlib and seaborn

# %%
pip install pandas matplotlib seaborn

# %% [markdown]
# # Step 1: Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Step 2: Load the CSV file into a pandas DataFrame

# %%
df = pd.read_csv('APU0000FF1101.csv', parse_dates=['DATE'])
df['APU0000FF1101'] = pd.to_numeric(df['APU0000FF1101'], errors='coerce')

# %% [markdown]
# ## Step 3: Inspect the data

# %%
print(df.info())
df.head(15)  # Display the first few rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224 entries, 0 to 223
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DATE           224 non-null    datetime64[ns]
#  1   APU0000FF1101  224 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 3.6 KB
# None
#          DATE  APU0000FF1101
# 0  2006-01-01          3.307
# 1  2006-02-01          3.341
# 2  2006-03-01          3.295
# 3  2006-04-01          3.308
# 4  2006-05-01          3.236
# 5  2006-06-01          3.277
# 6  2006-07-01          3.209
# 7  2006-08-01          3.357
# 8  2006-09-01          3.397
# 9  2006-10-01          3.280
# 10 2006-11-01          3.288
# 11 2006-12-01          3.284
# 12 2007-01-01          3.274
# 13 2007-02-01          3.259
# 14 2007-03-01          3.337

# %% [markdown]
# ## Step 4: Plot time series line graph

# %%
# Plot the time series data
plt.figure(figsize=(12, 8))
sns.lineplot(x='DATE', y='APU0000FF1101', data=df)

# Add labels and title
plt.title('Average Price - Chicken Breast, Boneless (Cost per Pound/453.6 Grams) in U.S. City Average Over Time')
plt.xlabel('Date')
plt.ylabel('Dollars')

# Display the plot
plt.grid(True)
plt.show()
